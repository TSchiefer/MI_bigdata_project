# %% [markdown]
# # Analysis of Amazon Product Data
#
# After construction of the graph (product-id and link to cross-buys), the following topics will be investigated:
# * correlation between in-degrees and salesrank
# * and some further smart questions... influence of number of reviews?, are there different sub-graphs like produkt categories?
# *
# *
# *
# Data source: https://snap.stanford.edu/data/amazon-meta.html

# %% [markdown]
# Data import

# %%
# Import graphframes (from Spark-Packages)
from graphframes import *
from pyspark.sql.functions import monotonically_increasing_id, desc


# Get the product data (already pre-processed data in table format)
products = spark.read.csv("/FileStore/tables/ProductData_small.csv", sep=";", header=True)

# The the cross-buy data (similar products)
links = spark.read.csv("/FileStore/tables/LinkData_small.csv", sep=";", header=True)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# How many products are we dealing with here?

# %%
products.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">5</span><span class="ansired">]: </span>10611
# </div>

# %% [markdown]
# quick check of the data formats

# %%
display(products.take(3))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Id</th><th>ASIN</th><th>Group</th><th>Salesrank</th><th>Reviews</th><th>avg rating</th><th>Title</th></tr></thead><tbody><tr><td>21</td><td>0790747324</td><td>DVD</td><td>795</td><td>140</td><td>4.5</td><td>The Time Machine</td></tr><tr><td>84</td><td>B000063W82</td><td>Video</td><td>780</td><td>14</td><td>4.5</td><td>The Best of Schoolhouse Rock! - 30th Anniversary Edition</td></tr><tr><td>252</td><td>B0000262WI</td><td>Music</td><td>581</td><td>82</td><td>4.5</td><td>The Köln Concert</td></tr></tbody></table></div>

# %% [markdown]
# And which and how many groups are there?

# %%
display(products.select("Group").distinct())
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Group</th></tr></thead><tbody><tr><td>Video</td></tr><tr><td>Toy</td></tr><tr><td>DVD</td></tr><tr><td>Sports</td></tr><tr><td>Baby Product</td></tr><tr><td>Video Games</td></tr><tr><td>Book</td></tr><tr><td>Music</td></tr><tr><td>Software</td></tr></tbody></table></div>

# %%
products.select("Group").distinct().count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">8</span><span class="ansired">]: </span>9
# </div>

# %% [markdown]
# And how many products per category?

# %%
display(products.groupBy('Group').count().sort('count', ascending=False))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Group</th><th>count</th></tr></thead><tbody><tr><td>Video</td><td>2933</td></tr><tr><td>Music</td><td>2855</td></tr><tr><td>Book</td><td>2535</td></tr><tr><td>DVD</td><td>2276</td></tr><tr><td>Software</td><td>5</td></tr><tr><td>Toy</td><td>4</td></tr><tr><td>Sports</td><td>1</td></tr><tr><td>Baby Product</td><td>1</td></tr><tr><td>Video Games</td><td>1</td></tr></tbody></table></div>

# %%
display(links.take(3))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>src</th><th>dest</th></tr></thead><tbody><tr><td>0790747324</td><td>B00007JMD8</td></tr><tr><td>0790747324</td><td>6305350221</td></tr><tr><td>0790747324</td><td>B00004RF9B</td></tr></tbody></table></div>

# %% [markdown]
# The graph will be constructed based on the product data. Each product is identified through its unique *ASIN* (Amazon Standard Identification Number) code
#
# GraphFrame library required *ASIN* to be renamed to *id*, but be careful, there is already an "Id" in the DataFrame

# %%
# rename "Id" to "Id-nu" to avoid any confusion (nu = not used)
# rename "ASIN" to "id"
ProductVertices = products.withColumnRenamed("Id", "Id-nu").distinct()
ProductVertices = ProductVertices.withColumnRenamed("ASIN", "id").distinct()
ProductVertices = ProductVertices.withColumnRenamed("avg rating", "avg_rating").distinct()

# check if done correctly
display(ProductVertices.take(3))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Id-nu</th><th>id</th><th>Group</th><th>Salesrank</th><th>Reviews</th><th>avg_rating</th><th>Title</th></tr></thead><tbody><tr><td>1698</td><td>6302796857</td><td>Video</td><td>424</td><td>28</td><td>4.5</td><td>A Town Like Alice</td></tr><tr><td>7524</td><td>B00000JWVS</td><td>DVD</td><td>88</td><td>58</td><td>4.5</td><td>Jerry Seinfeld Live on Broadway: I'm Telling You for the Last Time</td></tr><tr><td>10025</td><td>0393057658</td><td>Book</td><td>4371</td><td>252</td><td>4.5</td><td>Moneyball: The Art of Winning an Unfair Game</td></tr></tbody></table></div>

# %% [markdown]
# How does the Edge table look like?

# %%
display(links.take(1))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>src</th><th>dest</th></tr></thead><tbody><tr><td>0790747324</td><td>B00007JMD8</td></tr></tbody></table></div>

# %% [markdown]
# And how many edges are there?

# %%
links.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">13</span><span class="ansired">]: </span>52158
# </div>

# %% [markdown]
# Although not always strictly required, it's good practice to have an ID column for the tables.
#
# Since the product links does not have one yet, create and additional ID:

# %%
# 2. Create Edges
links = links.withColumn("link-id", monotonically_increasing_id())

display(links.take(3))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>src</th><th>dest</th><th>link-id</th></tr></thead><tbody><tr><td>0790747324</td><td>B00007JMD8</td><td>0</td></tr><tr><td>0790747324</td><td>6305350221</td><td>1</td></tr><tr><td>0790747324</td><td>B00004RF9B</td><td>2</td></tr></tbody></table></div>

# %% [markdown]
# Salesrank and number of reviews are read as string. Change type to int for calculations.

# %%
# change type of features "Salesrank" and "Reviews" to int
ProductVertices = ProductVertices.withColumn('Salesrank', ProductVertices.Salesrank.cast('int'))
ProductVertices = ProductVertices.withColumn('Reviews', ProductVertices.Reviews.cast('int'))
ProductVertices = ProductVertices.withColumn('avg rating', ProductVertices.avg_rating.cast('float'))
display(ProductVertices.take(1))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Id-nu</th><th>id</th><th>Group</th><th>Salesrank</th><th>Reviews</th><th>avg_rating</th><th>Title</th><th>avg rating</th></tr></thead><tbody><tr><td>1698</td><td>6302796857</td><td>Video</td><td>424</td><td>28</td><td>4.5</td><td>A Town Like Alice</td><td>4.5</td></tr></tbody></table></div>

# %% [markdown]
# Rename links to similar products ar *src* and *dst*

# %%
# rename destination "dest" to "dst"
links = links.withColumnRenamed('dest', 'dst')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# Now comes the moment of truth! Let's see if the graph can be constructed!

# %%
# Build the GraphFrame based on products and links

ProductGraph = GraphFrame(ProductVertices, links)

# print a sample of the vertices and edges
print("Products: %d" % ProductGraph.vertices.count())
print
print("SAMPLE PRODUCT DATA:")
print(ProductGraph.vertices.take(1))
print

print("Links: %d" % ProductGraph.edges.count())
print
print("SAMPLE LINK DATA:")
print(ProductGraph.edges.take(1))
print
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Products: 10611
# SAMPLE PRODUCT DATA:
# [Row(Id-nu=&apos;1698&apos;, id=&apos;6302796857&apos;, Group=&apos;Video&apos;, Salesrank=424, Reviews=28, avg_rating=&apos;4.5&apos;, Title=&apos;A Town Like Alice&apos;, avg rating=4.5)]
# Links: 52158
# SAMPLE LINK DATA:
# [Row(src=&apos;0790747324&apos;, dst=&apos;B00007JMD8&apos;, link-id=0)]
# <span class="ansired">Out[</span><span class="ansired">17</span><span class="ansired">]: </span>&lt;function print&gt;
# </div>

# %% [markdown]
# The Graph is constructed. Do the fancy analyses!

# %% [markdown]
# 1) assess the number of in-degress per product and compare it to the salesrank

# %% [markdown]
# Plot the next chunk in the following way:
#
# you can look at the distribution of the inDegree-values by clicking on the icon to the right of 'Raw table' and then chosing a histogram, values = 'inDegree' and  30 bins
#
# We can see that most of the inDegree values are between 0 and 2

# %%
display(ProductGraph.inDegrees.sort('inDegree', ascending=False))
#inDegRank = ProductGraph.inDegrees.sort('inDegree', ascending=False)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>inDegree</th></tr></thead><tbody><tr><td>B00008LDNZ</td><td>78</td></tr><tr><td>B00005JMAH</td><td>55</td></tr><tr><td>B00023P4I8</td><td>53</td></tr><tr><td>B00003CXCT</td><td>52</td></tr><tr><td>B000634DCW</td><td>45</td></tr><tr><td>B000068DBC</td><td>37</td></tr><tr><td>6304765266</td><td>36</td></tr><tr><td>B00005ATZT</td><td>34</td></tr><tr><td>B00001QEE7</td><td>33</td></tr><tr><td>B00005JMIJ</td><td>33</td></tr><tr><td>6305368171</td><td>33</td></tr><tr><td>1594480001</td><td>33</td></tr><tr><td>B0000TB01Y</td><td>32</td></tr><tr><td>B00003CXA2</td><td>30</td></tr><tr><td>630522577X</td><td>29</td></tr><tr><td>B0001NBLVI</td><td>29</td></tr><tr><td>B000059HB7</td><td>29</td></tr><tr><td>B0002CR04A</td><td>28</td></tr><tr><td>B0001I561E</td><td>28</td></tr><tr><td>6305696071</td><td>27</td></tr><tr><td>0684801523</td><td>27</td></tr><tr><td>B00005JMJG</td><td>27</td></tr><tr><td>B00003CX95</td><td>27</td></tr><tr><td>B000022TSH</td><td>27</td></tr><tr><td>B0002IVN9W</td><td>26</td></tr><tr><td>B000286RKW</td><td>26</td></tr><tr><td>B000000XB9</td><td>26</td></tr><tr><td>0316769487</td><td>24</td></tr><tr><td>B00005JMQZ</td><td>24</td></tr><tr><td>B00005JN4W</td><td>23</td></tr><tr><td>B0000DJZ8R</td><td>23</td></tr><tr><td>B000065DWB</td><td>23</td></tr><tr><td>B00005QFDX</td><td>23</td></tr><tr><td>B00003CXCQ</td><td>22</td></tr><tr><td>B0000026NF</td><td>22</td></tr><tr><td>B00000F14B</td><td>22</td></tr><tr><td>1400032717</td><td>22</td></tr><tr><td>B00012QM8G</td><td>22</td></tr><tr><td>B00005JKGO</td><td>21</td></tr><tr><td>B00005Y1XY</td><td>21</td></tr><tr><td>B00005V3Z4</td><td>21</td></tr><tr><td>B0002JP2OI</td><td>21</td></tr><tr><td>B0001NBMH6</td><td>21</td></tr><tr><td>B00001QEE6</td><td>21</td></tr><tr><td>B00005LKHZ</td><td>20</td></tr><tr><td>B00005LC4A</td><td>20</td></tr><tr><td>B00004RF97</td><td>20</td></tr><tr><td>B00005KARK</td><td>20</td></tr><tr><td>B00000K0DS</td><td>20</td></tr><tr><td>0790731479</td><td>20</td></tr><tr><td>B00005YUPQ</td><td>20</td></tr><tr><td>0446310786</td><td>20</td></tr><tr><td>B00008975Z</td><td>20</td></tr><tr><td>0694003611</td><td>19</td></tr><tr><td>B00001MXXH</td><td>19</td></tr><tr><td>B00005JMQW</td><td>19</td></tr><tr><td>B00008CMR4</td><td>19</td></tr><tr><td>B00005NTNW</td><td>19</td></tr><tr><td>0790729628</td><td>19</td></tr><tr><td>B0000AOV4I</td><td>19</td></tr><tr><td>B000067J1P</td><td>19</td></tr><tr><td>B00003CXE7</td><td>19</td></tr><tr><td>0140177396</td><td>19</td></tr><tr><td>6305280770</td><td>19</td></tr><tr><td>B0002YLCOM</td><td>19</td></tr><tr><td>B0002MPQRS</td><td>18</td></tr><tr><td>B00004R9A0</td><td>18</td></tr><tr><td>0805047905</td><td>18</td></tr><tr><td>B00003CX8Y</td><td>18</td></tr><tr><td>0399226907</td><td>18</td></tr><tr><td>B00005JKOI</td><td>18</td></tr><tr><td>B00005Q79A</td><td>18</td></tr><tr><td>0792839749</td><td>18</td></tr><tr><td>B0002I84JO</td><td>18</td></tr><tr><td>0800141660</td><td>18</td></tr><tr><td>6305168857</td><td>18</td></tr><tr><td>B00049QQJQ</td><td>18</td></tr><tr><td>0399501487</td><td>18</td></tr><tr><td>B00006FDCP</td><td>18</td></tr><tr><td>B00006RCO1</td><td>18</td></tr><tr><td>0066620996</td><td>18</td></tr><tr><td>B00000K31Q</td><td>18</td></tr><tr><td>B0002VEPRQ</td><td>17</td></tr><tr><td>0449214923</td><td>17</td></tr><tr><td>B00003JRCQ</td><td>17</td></tr><tr><td>B0001Z4OXS</td><td>17</td></tr><tr><td>B00003CXBU</td><td>17</td></tr><tr><td>0792165055</td><td>17</td></tr><tr><td>B0001L3MI0</td><td>17</td></tr><tr><td>B00000JS62</td><td>17</td></tr><tr><td>B00005NQJJ</td><td>17</td></tr><tr><td>6305144168</td><td>17</td></tr><tr><td>B00005JKDR</td><td>16</td></tr><tr><td>B00004XPPG</td><td>16</td></tr><tr><td>B00005PJ8V</td><td>16</td></tr><tr><td>0790729377</td><td>16</td></tr><tr><td>B00004KD24</td><td>16</td></tr><tr><td>B000055Y0X</td><td>16</td></tr><tr><td>B000002 ...

# %%
maxNumInDeg = ProductGraph.inDegrees.groupBy().max('inDegree')
display(maxNumInDeg)

maxNumInDegValue = str(maxNumInDeg.collect()[0]['max(inDegree)'])
#print(maxNumInDegValue)

maxInDegreeProduct = ProductGraph.inDegrees.filter('inDegree = {}'.format(maxNumInDegValue))
display(maxInDegreeProduct)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>inDegree</th></tr></thead><tbody><tr><td>B00008LDNZ</td><td>78</td></tr></tbody></table></div>

# %%
# join back to get product info based on max inDegree
ProductMaxInDegree = ProductGraph.vertices.join(maxInDegreeProduct, 'id')
display(ProductMaxInDegree)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>Id-nu</th><th>Group</th><th>Salesrank</th><th>Reviews</th><th>avg_rating</th><th>Title</th><th>avg rating</th><th>inDegree</th></tr></thead><tbody><tr><td>B00008LDNZ</td><td>548091</td><td>DVD</td><td>110</td><td>83</td><td>5.0</td><td>Laura</td><td>5.0</td><td>78</td></tr></tbody></table></div>

# %% [markdown]
# Plot the following chunk in this way:
# Plot this as a bar chart with 'Plot Options':
#  - Keys: InDegree
#  - Values: Salesrank
#
video</td><td>3810</td><td>10</td><td>3.5</td><td>The Importance of Being Earnest</td><td>3.5</td><td>1</td></tr><tr><td>B00005BGPK</td><td>209410</td><td>Video</td><td>4063</td><td>4</td><td>4.5</td><td>BMX Bandits</td><td>4.5</td><td>1</td></tr><tr><td>1573309788</td><td>165886</td><td>Video</td><td>3596</td><td>12</td><td>4.5</td><td>The Real World You Never Saw - Boston and Seattle</td><td>4.5</td><td>1</td></tr><tr><td>6301972228</td><td>464116</td><td>Video</td><td>4898</td><td>4</td><td>4.5</td><td>The Next Voice You Hear</td><td>4.5</td><td>1</td></tr><tr><td>6302816599</td><td>151078</td><td>Video</td><td>4020</td><td>16</td><td>4.5</td><td>Goodbye, My Lady</td><td>4.5</td><td>1</td></tr><tr><td>1930612001</td><td>80821</td><td>Video</td><td>2051</td><td>5</td><td>4.0</td><td>Transformations</td><td>4.0</td><td>1</td></tr><tr><td>0800121090</td><td>293341</td><td>Video</td><td>2536</td><td>9</td><td>3.0</td><td>Calendar Girl</td><td>3.0</td><td>1</td></tr><tr><td>1573625035</td><td>281510</td><td>Video</td><td>4730</td><td>8</td><td>3.0</td><td>Morgan Stewart's Coming Home</td><td>3.0</td><td>1</td></tr><tr><td>6304771746</td><td>313402</td><td>Video</td><td>4555</td><td>2</td><td>4.0</td><td>The Far Pavilions (EP V ...

# %% [markdown]
# outDegree is rather boring, since most of the products get assigned 5 products by default that are presumingly similar, as you can see here:

# %%
display(ProductSortOutDeg.groupBy("outDegree").count())
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>outDegree</th><th>count</th></tr></thead><tbody><tr><td>1</td><td>41</td></tr><tr><td>2</td><td>43</td></tr><tr><td>3</td><td>48</td></tr><tr><td>4</td><td>43</td></tr><tr><td>5</td><td>10343</td></tr></tbody></table></div>

# %% [markdown]
# plot the output of the next chunk in the following way:
# chose a scatter plot with options:
#   - values: Salesrank, Reviews
#   - LOESS bandwidth 0.47
#
# and apply to all rows.
# We can see a very weak dependency, suggesting that the less reviews a product has, the less likely it is to be a top selling product (a potential causal orientation might actually be inverse here...)

# %%
# relation of number of reviews and sales rank:
display(ProductGraph.vertices.select("Reviews", "Salesrank").sort("Reviews", ascending = False))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Reviews</th><th>Salesrank</th></tr></thead><tbody><tr><td>5545</td><td>110</td></tr><tr><td>5539</td><td>420</td></tr><tr><td>5539</td><td>2135</td></tr><tr><td>5039</td><td>170</td></tr><tr><td>5039</td><td>1533</td></tr><tr><td>5034</td><td>746</td></tr><tr><td>4924</td><td>404</td></tr><tr><td>4924</td><td>661</td></tr><tr><td>4924</td><td>327</td></tr><tr><td>3839</td><td>3221</td></tr><tr><td>3520</td><td>3494</td></tr><tr><td>3520</td><td>1616</td></tr><tr><td>3518</td><td>1676</td></tr><tr><td>3518</td><td>187</td></tr><tr><td>3051</td><td>3468</td></tr><tr><td>3049</td><td>19</td></tr><tr><td>2925</td><td>487</td></tr><tr><td>2925</td><td>2264</td></tr><tr><td>2922</td><td>761</td></tr><tr><td>2617</td><td>428</td></tr><tr><td>2568</td><td>3735</td></tr><tr><td>2568</td><td>60</td></tr><tr><td>2562</td><td>2872</td></tr><tr><td>2562</td><td>1599</td></tr><tr><td>2562</td><
# %% [markdown]
# what is the correlation coefficient between the two?

# %%
ProductGraph.vertices.stat.corr("Reviews", "Salesrank")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">36</span><span class="ansired">]: </span>-0.18539669378148713
# </div>

# %% [markdown]
# trying to find products which have an edge to another product which in turn has an edge to the first product:

# %%
ProductsWithBalancedSimilarity = ProductGraph.find("(v1)-[e1]->(v2); (v2)-[e2]->(v1)")
display(ProductsWithBalancedSimilarity)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>v1</th><th>e1</th><th>v2</th><th>e2</th></tr></thead><tbody><tr><td>List(21, 0790747324, DVD, 795, 140, 4.5, The Time Machine, 4.5)</td><td>List(0790747324, B00007JMD8, 0)</td><td>List(114681, B00007JMD8, DVD, 1076, 104, 4.5, Journey to the Center of the Earth, 4.5)</td><td>List(B00007JMD8, 0790747324, 11138)</td></tr><tr><td>List(84, B000063W82, Video, 780, 14, 4.5, The Best of Schoolhouse Rock! - 30th Anniversary Edition, 4.5)</td><td>List(B000063W82, 156949407X, 5)</td><td>List(239294, 156949407X, Video, 1223, 24, 5.0, Schoolhouse Rock! - Grammar Rock, 5.0)</td><td>List(156949407X, B000063W82, 22808)</td></tr><tr><td>List(296, 0385504209, Book, 19, 3049, 3.5, The Da Vinci Code, 3.5)</td><td>List(0385504209, 0671027360, 20)</td><td>List(376858, 0671027360, Book, 31, 1552, 4.0, Angels & Demons, 4.0)</td><td>List(0671027360, 0385504209, 34818)</td></tr><tr><td>List(296, 0385504209, Book, 19, 3049, 3.5, The Da Vinci Code, 3.5)</td><td>List(0385504209, 0671027387, 22)</td><td>List(424705, 0671027387, Book, 84, 429, 4.0, Deception Point, 4.0)</td><td>List(0671027387, 0385504209, 38171)</td></tr><tr><td>List(448, 0312966091, Book, 607, 141, 4.5, Three To Get Deadly : A Stephanie Plum Novel (A Stephanie Plum Novel), 4.5)</td><td>List(0312966091, 0312990456, 40)</td><td>List(471848, 0312990456, Book, 304, 414, 4.5, One for the Money (A Stephanie Plum Novel), 4.5)</td><td>List(0312990456, 0312966091, 41794)</td></tr><tr><td>List(448, 0312966091, Book, 607, 141, 4.5, Three To Get Deadly : A Stephanie Plum Novel (A Stephanie Plum Novel), 4.5)</td><td>List(0312966091, 0312971346, 41)</td><td>List(104366, 0312971346, Book, 1401, 264, 4.5, High Five (A Stephanie Plum Novel), 4.5)</td><td>List(0312971346, 0312966091, 10118)</td></tr><tr><td>List(448, 0312966091, Book, 607, 141, 4.5, Three To Get Deadly : A Stephanie Plum Novel (A Stephanie Plum Novel), 4.5)</td><td>List(0312966091, 0312976275, 42)</td><td>List(475036, 0312976275, Book, 787, 324, 4.5, Hot Six : A Stephanie Plum Novel (A Stephanie Plum Novel), 4.5)</td><td>List(0312976275, 0312966091, 41970)</td></tr><tr><td>List(448, 0312966091, Book, 607, 141, 4.5, Three To Get Deadly : A Stephanie Plum Novel (A Stephanie Plum Novel), 4.5)</td><td>List(0312966091, 0312980140, 43)</td><td>List(158327, 0312980140, Book, 1084, 274, 4.0, Seven Up (A Stephanie Plum Novel), 4.0)</td><td>List(0312980140, 0312966091, 15295)</td></tr><tr><td>List(457, B0000296JB, Music, 2439, 545, 4.5, Make Yourself, 4.5)</td><td>List(B0000296JB, B00005QG9J, 45)</td><td>List(119794, B00005QG9J, Music, 2488, 622, 4.5, Morning View, 4.5)</td><td>List(B00005QG9J, B0000296JB, 11691)</td></tr><tr><td>List(480, B0000296J9, Music, 1310, 42, 5.0, Gunfighter Ballads & Trail Songs, 5.0)</td><td>List(B0000296J9, B0000026AG, 50)</td><td>List(219235, B0000026AG, Music, 2015, 26, 5.0, Johnny Horton - Greatest Hits, 5.0)</td><td>List(B0000026AG, B0000296J9, 21158)</td></tr><tr><td>List(480, B0000296J9, Music, 1310, 42, 5.0, Gunfighter Ballads & Trail Songs, 5.0)</td><td>List(B0000296J9, B0000024YO, 51)</td><td>List(438745, B0000024YO, Music, 2293, 4, 4.5, Marty Robbins - All-Time Greatest Hits, 4.5)</td><td>List(B0000024YO, B0000296J9, 39218)</td></tr><tr><td>List(486, B0000296J3, Music, 1060, 46, 4.5, Stardust, 4.5)</td><td>List(B0000296J3, B00004U2G7, 55)</td><td>List(320882, B00004U2G7, Music, 709, 49, 5.0, Red Headed Stranger, 5.0)</td><td>List(B00004U2G7, B0000296J3, 30023)</td></tr><tr><td>List(486, B0000296J3, Music, 1060, 46, 4.5, Stardust, 4.5)</td><td>List(B0000296J3, B00008BXK3, 57)</td><td>List(394855, B00008BXK3, Music, 496, 15, 4.5, The Essential Willie Nelson, 4.5)</td><td>List(B00008BXK3, B0000296J3, 36016)</td></tr><tr><td>List(577, 0451163966, Book, 758, 316, 4.5, One Flew Over the Cuckoo's Nest, 4.5)</td><td>List(0451163966, 0393312836, 68)</td><td>List(196284, 0393312836, Book, 1073, 534, 4.5, ...

# %% [markdown]
# how many product-pairs reference each other? can we just calculate it like this?

# %%
ProductsWithBalancedSimilarity.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">32</span><span class="ansired">]: </span>11202
# </div>

# %% [markdown]
# does this mean, we have 11202 product-pairs that reference each other? Let's test if our data frame of mutually referencing products lists the pairs once or twice by looking at an example:

# %%
display(ProductsWithBalancedSimilarity.filter("(v1.id = '0790747324' and v2.id = 'B00007JMD8') or (v2.id = '0790747324' and v1.id = 'B00007JMD8')"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>v1</th><th>e1</th><th>v2</th><th>e2</th></tr></thead><tbody><tr><td>List(21, 0790747324, DVD, 795, 140, 4.5, The Time Machine, 4.5)</td><td>List(0790747324, B00007JMD8, 0)</td><td>List(114681, B00007JMD8, DVD, 1076, 104, 4.5, Journey to the Center of the Earth, 4.5)</td><td>List(B00007JMD8, 0790747324, 11138)</td></tr><tr><td>List(114681, B00007JMD8, DVD, 1076, 104, 4.5, Journey to the Center of the Earth, 4.5)</td><td>List(B00007JMD8, 0790747324, 11138)</td><td>List(21, 0790747324, DVD, 795, 140, 4.5, The Time Machine, 4.5)</td><td>List(0790747324, B00007JMD8, 0)</td></tr></tbody></table></div>

# %% [markdown]
# So the pairs are listed twice, which kind of makes sense, seeing how we constructed the data frame. This means there are 11202/2 = 5601 product-pairs that reference each other.

# %% [markdown]
# Now we want to explore if the "strongly connected components" of our graph are evenly distributed across all groups, which would mean that the probability of a DVD referencing to another DVD is the same as it referencing to e.g. a book, or if the groups tend to stick to themselves.
#
# Here we first calculate the strongly connected components
# (small warning: this command takes quite a while, ~1.17 hours, >250 jobs):

# %%
connectedComp = ProductGraph.stronglyConnectedComponents(maxIter=3)
#connectedComp.select("id", "component").groupBy("component").count().sort(desc("count")).show()

#ProductGraph.connectedComponents()
display(connectedComp)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>
><td>1486058684465</td><td>2</td></tr><tr><td>601295421501</td><td>2</td></tr><tr><td>876173328445</td><td>2</td></tr><tr><td>137438953488</td><td>2</td></tr><tr><td>137438953514</td><td>2</td></tr><tr><td>420906795031</td><td>2</td></tr><tr><td>77309411352</td><td>2</td></tr><tr><td>77309411362</td><td>2</td></tr><tr><td>180388626459</td><td>2</td></tr><tr><td>51539607587</td><td>1</td></tr><tr><td>781684047881</td><td>1</td></tr><tr><td>687194767365</td><td>1</td></tr><tr><td>781684047884</td><td>1</td></tr><tr><td>687194767368</td><td>1</td></tr><tr><td>687194767369</td><td>1</td></tr><tr><td>687194767370</td><td>1</td></tr><tr><td>652835029000</td><td>1</td></tr><tr><td>687194767374</td><td>1</td></tr><tr><td>687194767375</td><td>1</td></tr><tr><td>687194767376</td><td>1</td></tr><tr><td>687194767379</td><td>1</td></tr><tr><td>687194767380</td><td>1</td></tr><tr><td>6871947 ...

# %% [markdown]
# Next we get an overview how many clusters there are with members of *n* groups:

# %%
numGroupsCount = countComponentsNumberOfGroups.withColumnRenamed("count", "NumberOfGroupsForComponent").groupBy("NumberOfGroupsForComponent").count()
display(numGroupsCount)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>NumberOfGroupsForComponent</th><th>count</th></tr></thead><tbody><tr><td>4</td><td>1</td></tr><tr><td>3</td><td>6</td></tr><tr><td>2</td><td>77</td></tr><tr><td>1</td><td>6667</td></tr></tbody></table></div>

# %% [markdown]
# So how many clusters are there in total? Just adding up the values in column "count" in the last chunk results in the number of clusters:

# %%
display(numGroupsCount.agg({"count": "sum"}))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>sum(count)</th></tr></thead><tbody><tr><td>6751</td></tr></tbody></table></div>

# %% [markdown]
# 6751 is a very high number, seeing that there are just 10611 products in our dataset in total.

# %% [markdown]
# And what is the size distribution of the clusters in general (independent which groups its members belong to)?

# %%
countConnected = connectedComp.groupBy("component").count().sort(desc("count"))
display(countConnected)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>component</th><th>count</th></tr></thead><tbody><tr><td>23</td><td>988</td></tr><tr><td>51539607567</td><td>29</td></tr><tr><td>60129542167</td><td>25</td></tr><tr><td>8589934634</td><td>21</td></tr><tr><td>154618822687</td><td>21</td></tr><tr><td>197568495616</td><td>19</td></tr><tr><td>163208757252</td><td>19</td></tr><tr><td>94489280561</td><td>19</td></tr><tr><td>19</td><td>16</td></tr><tr><td>343597383724</td><td>15</td></tr><tr><td>51539607594</td><td>14</td></tr><tr><td>51539607602</td><td>14</td></tr><tr><td>214748364856</td><td>14</td></tr><tr><td>94489280564</td><td>13</td></tr><tr><td>85899345942</td><td>13</td></tr><tr><td>163208757279</td><td>13</td></tr><tr><td>77309411362</td><td>12</td></tr><tr><td>17179869199</td><td>12</td></tr><tr><td>103079215153</td><td>11</td></tr><tr><td>154618822666</td><td>11</td></tr><tr><td>13</td><td>11</td></tr><tr><td>17179869225</td><td>11</td></tr><tr><td>206158430226</td><td>10</td></tr><tr><td>47</td><td>10</td></tr><tr><td>120259084303</td><td>10</td></tr><tr><td>403726925830</td><td>10</td></tr><tr><td>137438953501</td><td>10</td></tr><tr><td>180388626432</td><td>10</td></tr><tr><td>25769803800</td><td>10</td></tr><tr><