# %% [markdown]
# # Analysis of Amazon Product Data
#
# After construction of the graph (product-id and link to cross-buys), the following topics will be investigated:
# * correlation between in-degrees and salesrank
# * and some further smart questions... influence of number of reviews?, are there different sub-graphs like produkt categories?
# *
# *
# *
# Data source: https://snap.stanford.edu/data/amazon-meta.html

# %% [markdown]
# Data import

# %%
# Import graphframes (from Spark-Packages)

from graphframes import *
from pyspark.sql.functions import monotonically_increasing_id, desc


# Get the product data (already pre-processed data in table format)
products = spark.read.csv("/FileStore/tables/ProductData_small.csv", sep=";", header=True)

# The the cross-buy data (similar products)
links = spark.read.csv("/FileStore/tables/LinkData_small.csv", sep=";", header=True)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# How many products are we dealing with here?

# %%
products.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">10</span><span class="ansired">]: </span>10611
# </div>

# %% [markdown]
# quick check of the data formats

# %%
display(products.take(3))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Id</th><th>ASIN</th><th>Group</th><th>Salesrank</th><th>Reviews</th><th>Title</th></tr></thead><tbody><tr><td>21</td><td>0790747324</td><td>DVD</td><td>795</td><td>140</td><td>The Time Machine</td></tr><tr><td>84</td><td>B000063W82</td><td>Video</td><td>780</td><td>14</td><td>The Best of Schoolhouse Rock! - 30th Anniversary Edition</td></tr><tr><td>252</td><td>B0000262WI</td><td>Music</td><td>581</td><td>82</td><td>The Köln Concert</td></tr></tbody></table></div>

# %% [markdown]
# And which and how many groups are there?

# %%
display(products.select("Group").distinct())
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Group</th></tr></thead><tbody><tr><td>Video</td></tr><tr><td>Toy</td></tr><tr><td>DVD</td></tr><tr><td>Sports</td></tr><tr><td>Baby Product</td></tr><tr><td>Video Games</td></tr><tr><td>Book</td></tr><tr><td>Music</td></tr><tr><td>Software</td></tr></tbody></table></div>

# %%
products.select("Group").distinct().count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">13</span><span class="ansired">]: </span>9
# </div>

# %% [markdown]
# And how many products per category?

# %%
display(products.groupBy('Group').count().sort('count', ascending=False))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Group</th><th>count</th></tr></thead><tbody><tr><td>Video</td><td>2933</td></tr><tr><td>Music</td><td>2855</td></tr><tr><td>Book</td><td>2535</td></tr><tr><td>DVD</td><td>2276</td></tr><tr><td>Software</td><td>5</td></tr><tr><td>Toy</td><td>4</td></tr><tr><td>Sports</td><td>1</td></tr><tr><td>Baby Product</td><td>1</td></tr><tr><td>Video Games</td><td>1</td></tr></tbody></table></div>

# %%
display(links.take(3))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>src</th><th>dest</th></tr></thead><tbody><tr><td>0790747324</td><td>B00007JMD8</td></tr><tr><td>0790747324</td><td>B00004RF9B</td></tr><tr><td>0790747324</td><td>B00005JKFR</td></tr></tbody></table></div>

# %% [markdown]
# The graph will be constructed based on the product data. Each product is identified through its unique *ASIN* (Amazon Standard Identification Number) code
#
# GraphFrame library required *ASIN* to be renamed to *id*, but be careful, there is already an "Id" in the DataFrame

# %%
# rename "Id" to "Id-nu" to avoid any confusion (nu = not used)
# rename "ASIN" to "id"
ProductVertices = products.withColumnRenamed("Id", "Id-nu").distinct()
ProductVertices = ProductVertices.withColumnRenamed("ASIN", "id").distinct()

# check if done correctly
display(ProductVertices.take(3))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Id-nu</th><th>id</th><th>Group</th><th>Salesrank</th><th>Reviews</th><th>Title</th></tr></thead><tbody><tr><td>13260</td><td>B000002TIR</td><td>Music</td><td>2004</td><td>16</td><td>French Kiss</td></tr><tr><td>13683</td><td>0140281916</td><td>Book</td><td>2877</td><td>16</td><td>Bargaining for Advantage : Negotiation Strategies for Reasonable People</td></tr><tr><td>30773</td><td>B000001EYO</td><td>Music</td><td>3579</td><td>31</td><td>The Big Lebowski: Original Motion Picture Soundtrack</td></tr></tbody></table></div>

# %% [markdown]
# How does the Edge table look like?

# %%
display(links.take(1))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>src</th><th>dest</th></tr></thead><tbody><tr><td>0790747324</td><td>B00007JMD8</td></tr></tbody></table></div>

# %% [markdown]
# Although not always strictly required, it's good practice to have an ID column for the tables.
#
# Since the product links does not have one yet, create and additional ID:

# %%
# 2. Create Edges
links = links.withColumn("link-id", monotonically_increasing_id())

display(links.take(3))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>src</th><th>dest</th><th>link-id</th></tr></thead><tbody><tr><td>0790747324</td><td>B00007JMD8</td><td>0</td></tr><tr><td>0790747324</td><td>B00004RF9B</td><td>1</td></tr><tr><td>0790747324</td><td>B00005JKFR</td><td>2</td></tr></tbody></table></div>

# %% [markdown]
# Salesrank and number of reviews are read as string. Change type to int for calculations.

# %%
# change type of features "Salesrank" and "Reviews" to int
ProductVertices = ProductVertices.withColumn('Salesrank', ProductVertices.Salesrank.cast('int'))
ProductVertices = ProductVertices.withColumn('Reviews', ProductVertices.Reviews.cast('int'))
display(ProductVertices.take(1))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Id-nu</th><th>id</th><th>Group</th><th>Salesrank</th><th>Reviews</th><th>Title</th></tr></thead><tbody><tr><td>13260</td><td>B000002TIR</td><td>Music</td><td>2004</td><td>16</td><td>French Kiss</td></tr></tbody></table></div>

# %% [markdown]
# Rename links to similar products ar *src* and *dst*

# %%
# rename destination "dest" to "dst"
links = links.withColumnRenamed('dest', 'dst')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# Now comes the moment of truth! Let's see if the graph can be constructed!

# %%
# Build the GraphFrame based on products and links

ProductGraph = GraphFrame(ProductVertices, links)

# print a sample of the vertices and edges
print("Products: %d" % ProductGraph.vertices.count())
print
print("SAMPLE PRODUCT DATA:")
print(ProductGraph.vertices.take(1))
print

print("Links: %d" % ProductGraph.edges.count())
print
print("SAMPLE LINK DATA:")
print(ProductGraph.edges.take(1))
print
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Products: 10611
# SAMPLE PRODUCT DATA:
# [Row(Id-nu=&apos;13260&apos;, id=&apos;B000002TIR&apos;, Group=&apos;Music&apos;, Salesrank=2004, Reviews=16, Title=&apos;French Kiss&apos;)]
# Links: 21560
# SAMPLE LINK DATA:
# [Row(src=&apos;0790747324&apos;, dst=&apos;B00007JMD8&apos;, link-id=0)]
# <span class="ansired">Out[</span><span class="ansired">21</span><span class="ansired">]: </span>&lt;function print&gt;
# </div>

# %% [markdown]
# The Graph is constructed. Do the fancy analyses!

# %% [markdown]
# 1) assess the number of in-degress per product and compare it to the salesrank

# %% [markdown]
# Plot chunk 24 in the following way:
#
# you can look at the distribution of the inDegree-values by clicking on the icon to the right of 'Raw table' and then chosing a histogram, values = 'inDegree' and  30 bins
#
# We can see that most of the inDegree values are between 0 and 2

# %%
display(ProductGraph.inDegrees.sort('inDegree', ascending=False))
#inDegRank = ProductGraph.inDegrees.sort('inDegree', ascending=False)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>inDegree</th></tr></thead><tbody><tr><td
BK</td><td>16</td></tr><tr><td>B00003CXC7</td><td>16</td></tr><tr><td>0790729377</td><td>16</td></tr><tr><td>0440237688</td><td>16</td></tr><tr><td>B000055Y0X</td><td>16</td></tr><tr><td>0783117523</td><td>15</td></tr><tr><td>1568322267</td><td>15</td></tr><tr><td>0553210092</td><td>15</td></tr><tr><td>B00000DHZJ</td><td>15</td></tr><tr><td>B00005S6K8</td><td>15</td></tr><tr><td>6304696566</td><td>15</td></tr><tr><td>1568328478</td><td>15</td></tr><tr><td>B00002CGGH</td><td>15</td></tr><tr><td>6305212112</td><td>15</td></tr><tr><td>B000035Z1Z</td><td>15</td></tr><tr><td>0792833287</td><td>15</td></tr><tr><td>B00004VVNB</td><td>15</td></tr><tr><td>6303144535</td><td>15</td></tr><tr><td>0440498058</td><td>15</td></tr><tr><td>B00003CXD3</td><td>15</td></tr><tr><td>B00003CXAT</td><td>15</td></tr><tr><td>B000056WQX</td><td>14</td></tr><tr><td>B0000058HV</td><td>14</td></tr><tr><td>0451526341</td><td>14</td></tr><tr><td>B0000062XS</td><td>14</td></tr><tr><td>B00005R87R</td><td>14</td></tr><tr><td>6305428476</td><td>14</td></tr><tr><td>B00006J ...

# %%
maxNumInDeg = ProductGraph.inDegrees.groupBy().max('inDegree')
display(maxNumInDeg)

maxNumInDegValue = str(maxNumInDeg.collect()[0]['max(inDegree)'])
#print(maxNumInDegValue)

maxInDegreeProduct = ProductGraph.inDegrees.filter('inDegree = {}'.format(maxNumInDegValue))
display(maxInDegreeProduct)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>inDegree</th></tr></thead><tbody><tr><td>B00008LDNZ</td><td>78</td></tr></tbody></table></div>

# %%
# join back to get product info based on max inDegree
ProductMaxInDegree = ProductGraph.vertices.join(maxInDegreeProduct, 'id')
display(ProductMaxInDegree)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>Id-nu</th><th>Group</th><th>Salesrank</th><th>Reviews</th><th>Title</th><th>inDegree</th></tr></thead><tbody><tr><td>B00008LDNZ</td><td>548091</td><td>DVD</td><td>110</td><td>83</td><td>Laura</td><td>78</td></tr></tbody></table></div>

# %% [markdown]
# Plot the following chunk in this way:
# Plot this as a bar chart with 'Plot Options':
#  - Keys: InDegree
#  - Values: Salesrank
#
# Unfortunately you can't chose to have a logarithmic y-axis, but you do see that at least for low in-degree values the sales rank is rather bad.
#
# Alternative: scatterplot inDegree vs. salesrank and grouping by product group (Keys=Group)

# %%
# repeat exercise from above but with entire list
selection = ProductGraph.inDegrees.sort('inDegree', ascending=False)
#display(selection)

ProductSortInDeg = ProductGraph.vertices.join(selection, 'id').sort('inDegree', ascending=False)
display(ProductSortInDeg)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>Id-nu</th><th>Group</th><th>Salesrank</th><th>Reviews</th><th>Title</th><th>inDegree</th></tr></thead><tbody><tr><td>B00008LDNZ</td><td>548091</td><td>DVD</td><td>110</td><td>83</td><td>Laura</td><td>78</td></tr><tr><td>B000068DBC</td><td>546689</td><td>DVD</td><td>109</td><td>633</td><td>Pulp Fiction (Collector's Edition)</td><td>37</td></tr><tr><td>6304765266</td><td>97579</td><td>DVD</td><td>351</td><td>152</td><td>While You Were Sleeping</td><td>36</td></tr><tr><td>B00005ATZT</td><td>547040</td><td>DVD</td><td>1020</td><td>140</td><td>The Fugitive
three To Get Deadly : A Stephanie Plum Novel (A Stephanie Plum Novel))</td><td>List(0312966091, 0312990456, 12)</td><td>List(471848, 0312990456, Book, 304, 414, One for the Money (A Stephanie Plum Novel))</td><td>List(0312990456, 0312966091, 16904)</td></tr><tr><td>List(448, 0312966091, Book, 607, 141, Three To Get Deadly : A Stephanie Plum Novel (A Stephanie Plum Novel))</td><td>List(0312966091, 0312971346, 13)</td><td>List(104366, 0312971346, Book, 1401, 264, High Five (A Stephanie Plum Novel))</td><td>List(0312971346, 0312966091, 4164)</td></tr><tr><td>List(448, 0312966091, Book, 607, 141, Three To Get Deadly : A Stephanie Plum Novel (A Stephanie Plum Novel))</td><td>List(0312966091, 0312976275, 14)</td><td>List(475036, 0312976275, Book, 787, 324, Hot Six : A Stephanie Plum Novel (A Stephanie Plum Novel))</td><td>List(0312976275, 0312966091, 16978)</td></tr><tr><td>List(448, 0312966091, Book, 607, 141, Three To Get Deadly : A Stephanie Plum Novel (A Stephanie Plum Novel))</td><td>List(0312966091, 0312980140, 15)</td><td>List(158327, 0312980140, Book, 1084, 274, Seven Up (A Stephanie Plum Novel))</td><td>List(0312980140, 0312966091, 6266)</td></tr><tr><td>List(457, B0000296JB, Music, 2439, 545, Make Yourself)</td><td>List(B0000296JB, B00005QG9J, 17)</td><td>List(119794, B00005QG9J, Music, 2488, 622, Morning View)</td><td>List(B00005QG9J, B0000296JB, 4782)</td></tr><tr><td>List(480, B0000296J9, Music, 1310, 42, Gunfighter Ballads & Trail Songs)</td><td>List(B0000296J9, B0000026AG, 18)</td><td>List(219235, B0000026AG, Music, 2015, 26, Johnny Horton - Greatest Hits)</td><td>List(B0000026AG, B0000296J9, 8681)</td></tr><tr><td>List(480, B0000296J9, Music, 1310, 42, Gunfighter Ballads & Trail Songs)</td><td>List(B0000296J9, B0000024YO, 19)</td><td>List(438745, B0000024YO, Music, 2293, 4, Marty Robbins - All-Time Greatest Hits)</td><td>List(B0000024YO, B0000296J9, 15892)</td></tr><tr><td>List(486, B0000296J3, Music, 1060, 46, Stardust)</td><td>List(B0000296J3, B00004U2G7, 20)</td><td>List(320882, B00004U2G7, Music, 709, 49, Red Headed Stranger)</td><td>List(B00004U2G7, B0000296J3, 12192)</td></tr><tr><td>List(486, B0000296J3, Music, 1060, 46, Stardust)</td><td>List(B0000296J3, B00008BXK3, 21)</td><td>List(394855, B00008BXK3, Music, 496, 15, The Essential Willie Nelson)</td><td>List(B00008BXK3, B0000296J3, 14603)</td></tr><tr><td>List(577, 0451163966, Book, 758, 316, One Flew Over the Cuckoo's Nest)</td><td>List(0451163966, 0393312836, 28)</td><td>List(196284, 0393312836, Book, 1073, 534, A Clockwork Orange (Norton Paperback Fiction))</td><td>List(0393312836, 0451163966, 7889)</td></tr><tr><td>List(600, B000002V0T, Music, 3430, 55, American Patriot)</td><td>List(B000002V0T, B00005QJDD, 30)</td><td>List(162660, B00005QJDD, Music, 3422, 59, God Bless America)</td><td ...

# %% [markdown]
# how many product-pairs reference each other? can we just calculate it like this?

# %%
ProductsWithBalancedSimilarity.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">37</span><span class="ansired">]: </span>11202
# </div>

# %% [markdown]
# does this mean, we have 11202 product-pairs that reference each other? Let's test if our data frame of mutually referencing products lists the pairs once or twice by looking at an example:

# %%
display(ProductsWithBalancedSimilarity.filter("(v1.id = '0790747324' and v2.id = 'B00007JMD8') or (v2.id = '0790747324' and v1.id = 'B00007JMD8')"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>v1</th><th>e1</th><th>v2</th><th>e2</th></tr></thead><tbody><tr><td>List(21, 0790747324, DVD, 795, 140, The Time Machine)</td><td>List(0790747324, B00007JMD8, 0)</td><td>List(114681, B00007JMD8, DVD, 1076, 104, Journey to the Center of the Earth)</td><td>List(B00007JMD8, 0790747324, 4581)</td></tr><tr><td>List(114681, B00007JMD8, DVD, 1076, 104, Journey to the Center of the Earth)</td><td>List(B00007JMD8, 0790747324, 4581)</td><td>List(21, 0790747324, DVD, 795, 140, The Time Machine)</td><td>List(0790747324, B00007JMD8, 0)</td></tr></tbody></table></div>

# %% [markdown]
# So the pairs are listed twice, which kind of makes sense, seeing how we constructed the data frame. This means there are 11202/2 = 5601 product-pairs that reference each other.

# %% [markdown]
# Now we want to explore if the "strongly connected components" of our graph are evenly distributed across all groups, which would mean that the probability of a DVD referencing to another DVD is the same as it referencing to e.g. a book, or if the groups tend to stick to themselves.
#
# Here we first calculate the strongly connected components
# (small warning: this command takes quite a while, ~1.17 hours, 238 jobs):

# %%
connectedComp = ProductGraph.stronglyConnectedComponents(maxIter=3)
#connectedComp.select("id", "component").groupBy("component").count().sort(desc("count")).show()

#ProductGraph.connectedComponents()
display(connectedComp)

# %% [markdown]
# The connected components are marked by the same value in the column "component". So if we group the data frame by "component" and "Group" and use the function "count()", we will have as many rows per "component" value as the number of different groups belonging to this cluster.

# %%
countGroupComponent= connectedComp.groupBy("component", "Group").count().sort("component")
display(countGroupComponent)

# %% [markdown]
# Now how many groups are taking part in each cluster?

# %%
countComponentsNumberOfGroups = countGroupComponent.groupBy("component").count().sort(desc("count"))
display(countComponentsNumberOfGroups)

# %% [markdown]
# Next we get an overview how many clusters there are with members of *n* groups:

# %%
numGroupsCount = countComponentsNumberOfGroups.withColumnRenamed("count", "NumberOfGroupsForComponent").groupBy("NumberOfGroupsForComponent").count()
display(numGroupsCount)

# %% [markdown]
# So how many clusters are there in total? Just adding up the values in column "count" in the last chunk results in the number of clusters:

# %%
display(numGroupsCount.agg({"count": "sum"}))

# %% [markdown]
# 6751 is a very high number, seeing that there are just 10611 products in our dataset in total.

# %% [markdown]
# And what is the size distribution of the clusters in general (independent which groups its members belong to)?

# %%
countConnected = connectedComp.groupBy("component").count().sort(desc("count"))
display(countConnected)

# %% [markdown]
# So there is only one really huge cluster of strongly connected components with almost 1000 members. The next biggest one has only a size of 29.

# %% [markdown]
# How many of the 6751 clusters have more than 3 members?

# %%
countConnected.filter("count > 3").count()
